# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
from tools import *
import operator
import itertools

# %%
torch.cuda.is_available()
torch.cuda.current_device()
# Out:
# 0

# %%
train_data=torchvision.datasets.MNIST('./', train=True, download=True,transform=torchvision.transforms.ToTensor())
test_data=torchvision.datasets.MNIST('./', train=False, download=True,transform=torchvision.transforms.ToTensor())
# train_loader = torch.utils.data.DataLoader(train_data, batch_size=100, shuffle=True)
# test_loader = torch.utils.data.DataLoader(test_data, batch_size=100, shuffle=True)

# %%
train_data_list=[]
train_label_list=[]
for x,y in train_data:
    train_data_list.append(x)
    train_label_list.append(y)
    
test_data_list=[]
test_label_list=[]
for x,y in test_data:
    test_data_list.append(x)
    test_label_list.append(y)
    
train_data_tensor=torch.stack(train_data_list)
train_label_tensor=torch.tensor(train_label_list)
test_data_tensor=torch.stack(test_data_list)
test_label_tensor=torch.tensor(test_label_list)

print(train_data_tensor.size())
print(train_label_tensor.size())
print(test_data_tensor.size())
print(test_label_tensor.size())
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# torch.Size([10000, 1, 28, 28])
# torch.Size([10000])

# %%
class Net(nn.Module):
    def __init__(self,feature_dim):
        super(Net, self).__init__()
        self.feature_dim=feature_dim        
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.fc1 = nn.Linear(320, 100)
        self.fc2 = nn.Linear(100, feature_dim)
        self.fc3 = nn.Linear(feature_dim,10)
        
        self.optimizer = optim.Adam(self.parameters(), lr=0.001)

    def forward(self, x):
        x=x.view(-1,1,28,28)
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x =torch.tanh(self.fc2(x))
        x= self.fc3(x)
        return F.log_softmax(x,dim=-1)
        
    def predictive_distribution_entropy(self,x):
        with torch.no_grad():
            batch_logit=self.forward(x)
            batch_probs=torch.exp(batch_logit)
            batch_entropy=-torch.sum(batch_logit*batch_probs,dim=-1)
#             print(batch_entropy.size())
        return batch_entropy

        
    
    def train(self,x,label):
        train_losses = []
        if x.size(0)<100:
            batch_size=x.size(0)
            iteration=1
        else:
            batch_size=100
            iteration=int(x.size(0)/batch_size)
        batch_size=100
        for epoch in range(0,1000):
#             if epoch%100==0:
#                 print('learning_epoch:',epoch)
            for it in range(0,iteration):
                index=np.random.choice(x.size(0),batch_size)
                self.optimizer.zero_grad()
                output = self.forward(x[index])
                nll_loss= F.nll_loss(output,label[index],reduction='sum')
                nll_loss.backward()
                self.optimizer.step()
                train_losses.append(nll_loss.item())
#         plt.title('training_accuracy')
#         plt.plot(train_losses)
#         plt.show()
        return train_losses
    
    def test(self,x,label):
        pred = (self.forward(x).data.max(dim=1, keepdim=True)[1]).view(-1)
#         print(pred)
#         print(label)
#         print(torch.nonzero(pred-label))
        accuracy=(pred == label).sum().item()/label.size(0)
        return accuracy
    
        
#     def test(self):
#         correct=0
#         for data, target in test_loader:
#             pred = self.predict(data)
#             correct += pred.eq(target.data.view_as(pred)).sum()
#             correct_ratio= float(correct)/len(test_loader.dataset)
#         return correct_ratio

# %%
nn_tanh = Net(feature_dim=20).cuda()
init_train_data=train_data_tensor[0:10].cuda()
init_train_label=train_label_tensor[0:10].cuda()
accuracy_list=[]
for epoch in range(0,100):
    print('big_epoch:', epoch, 'start training...')
    print('train_data_size',init_train_label.size(0))
    nn_tanh.train(init_train_data,init_train_label)
    
    accuracy=nn_tanh.test(test_data_tensor.cuda(),test_label_tensor.cuda())
    accuracy_list.append(accuracy)
    print('epoch:', epoch, 'test_accuracy', accuracy)
#     plt.title('test_accuracy')
#     plt.plot(accuracy_list)
#     plt.show()
#     accuracy_list.append(accuracy)
    ### active part
#     print('epoch:', epoch, 'start active learning...')
    for i in range(0,10):
        active_batch_data=train_data_tensor[i*6000:(i+1)*6000].cuda()
        entropy_list=nn_tanh.predictive_distribution_entropy(active_batch_data)
        _, index = entropy_list.max(0)
        init_train_data=torch.cat((init_train_data,active_batch_data[index].view(1,1,28,28).cuda()),0)
        init_train_label=torch.cat((init_train_label,train_label_tensor[index+i*6000].view(-1).cuda()),0)
        
plt.title('test_accuracy')
plt.plot(accuracy_list)
plt.show()
print(accuracy_list)
# Out:
# big_epoch: 0 start training...
# train_data_size 10
# epoch: 0 test_accuracy 0.4085
# big_epoch: 1 start training...
# train_data_size 20
# epoch: 1 test_accuracy 0.4948
# big_epoch: 2 start training...
# train_data_size 30
# epoch: 2 test_accuracy 0.6042
# big_epoch: 3 start training...
# train_data_size 40
# epoch: 3 test_accuracy 0.6745
# big_epoch: 4 start training...
# train_data_size 50
# epoch: 4 test_accuracy 0.7165
# big_epoch: 5 start training...
# train_data_size 60
# epoch: 5 test_accuracy 0.7289
# big_epoch: 6 start training...
# train_data_size 70
# epoch: 6 test_accuracy 0.7411
# big_epoch: 7 start training...
# train_data_size 80
# epoch: 7 test_accuracy 0.7988
# big_epoch: 8 start training...
# train_data_size 90
# epoch: 8 test_accuracy 0.817
# big_epoch: 9 start training...
# train_data_size 100
# epoch: 9 test_accuracy 0.8099
# big_epoch: 10 start training...
# train_data_size 110
# epoch: 10 test_accuracy 0.8402
# big_epoch: 11 start training...
# train_data_size 120
# epoch: 11 test_accuracy 0.8379
# big_epoch: 12 start training...
# train_data_size 130
# epoch: 12 test_accuracy 0.8596
# big_epoch: 13 start training...
# train_data_size 140
# epoch: 13 test_accuracy 0.8636
# big_epoch: 14 start training...
# train_data_size 150
# epoch: 14 test_accuracy 0.8847
# big_epoch: 15 start training...
# train_data_size 160
# epoch: 15 test_accuracy 0.8884
# big_epoch: 16 start training...
# train_data_size 170
# epoch: 16 test_accuracy 0.8896
# big_epoch: 17 start training...
# train_data_size 180
# epoch: 17 test_accuracy 0.8921
# big_epoch: 18 start training...
# train_data_size 190
# epoch: 18 test_accuracy 0.8998
# big_epoch: 19 start training...
# train_data_size 200
# epoch: 19 test_accuracy 0.8991
# big_epoch: 20 start training...
# train_data_size 210
# epoch: 20 test_accuracy 0.9029
# big_epoch: 21 start training...
# train_data_size 220
# epoch: 21 test_accuracy 0.901
# big_epoch: 22 start training...
# train_data_size 230
# epoch: 22 test_accuracy 0.906
# big_epoch: 23 start training...
# train_data_size 240
# epoch: 23 test_accuracy 0.9173
# big_epoch: 24 start training...
# train_data_size 250
# epoch: 24 test_accuracy 0.913
# big_epoch: 25 start training...
# train_data_size 260
# epoch: 25 test_accuracy 0.9195
# big_epoch: 26 start training...
# train_data_size 270
# epoch: 26 test_accuracy 0.9249
# big_epoch: 27 start training...
# train_data_size 280
# epoch: 27 test_accuracy 0.918
# big_epoch: 28 start training...
# train_data_size 290
# epoch: 28 test_accuracy 0.9189
# big_epoch: 29 start training...
# train_data_size 300
# epoch: 29 test_accuracy 0.9252
# big_epoch: 30 start training...
# train_data_size 310
# epoch: 30 test_accuracy 0.9269
# big_epoch: 31 start training...
# train_data_size 320
# epoch: 31 test_accuracy 0.927
# big_epoch: 32 start training...
# train_data_size 330
# epoch: 32 test_accuracy 0.9374
# big_epoch: 33 start training...
# train_data_size 340
# epoch: 33 test_accuracy 0.9314
# big_epoch: 34 start training...
# train_data_size 350
# epoch: 34 test_accuracy 0.9397
# big_epoch: 35 start training...
# train_data_size 360
# epoch: 35 test_accuracy 0.9406
# big_epoch: 36 start training...
# train_data_size 370
# epoch: 36 test_accuracy 0.9374
# big_epoch: 37 start training...
# train_data_size 380
# epoch: 37 test_accuracy 0.9347
# big_epoch: 38 start training...
# train_data_size 390
# epoch: 38 test_accuracy 0.9482
# big_epoch: 39 start training...
# train_data_size 400
# epoch: 39 test_accuracy 0.9457
# big_epoch: 40 start training...
# train_data_size 410
# epoch: 40 test_accuracy 0.9434
# big_epoch: 41 start training...
# train_data_size 420
# epoch: 41 test_accuracy 0.9511
# big_epoch: 42 start training...
# train_data_size 430
# epoch: 42 test_accuracy 0.9396
# big_epoch: 43 start training...
# train_data_size 440
# epoch: 43 test_accuracy 0.9467
# big_epoch: 44 start training...
# train_data_size 450
# epoch: 44 test_accuracy 0.9443
# big_epoch: 45 start training...
# train_data_size 460
# epoch: 45 test_accuracy 0.9449
# big_epoch: 46 start training...
# train_data_size 470
# epoch: 46 test_accuracy 0.9444
# big_epoch: 47 start training...
# train_data_size 480
# epoch: 47 test_accuracy 0.9512
# big_epoch: 48 start training...
# train_data_size 490
# epoch: 48 test_accuracy 0.9463
# big_epoch: 49 start training...
# train_data_size 500
# epoch: 49 test_accuracy 0.9475
# big_epoch: 50 start training...
# train_data_size 510
# epoch: 50 test_accuracy 0.953
# big_epoch: 51 start training...
# train_data_size 520
# epoch: 51 test_accuracy 0.947
# big_epoch: 52 start training...
# train_data_size 530
# epoch: 52 test_accuracy 0.9498
# big_epoch: 53 start training...
# train_data_size 540
# epoch: 53 test_accuracy 0.956
# big_epoch: 54 start training...
# train_data_size 550
# epoch: 54 test_accuracy 0.9558
# big_epoch: 55 start training...
# train_data_size 560
# epoch: 55 test_accuracy 0.9567
# big_epoch: 56 start training...
# train_data_size 570
# epoch: 56 test_accuracy 0.9573
# big_epoch: 57 start training...
# train_data_size 580
# epoch: 57 test_accuracy 0.9586
# big_epoch: 58 start training...
# train_data_size 590
# epoch: 58 test_accuracy 0.9597
# big_epoch: 59 start training...
# train_data_size 600
# epoch: 59 test_accuracy 0.9581
# big_epoch: 60 start training...
# train_data_size 610
# epoch: 60 test_accuracy 0.9599
# big_epoch: 61 start training...
# train_data_size 620
# epoch: 61 test_accuracy 0.9606
# big_epoch: 62 start training...
# train_data_size 630
# epoch: 62 test_accuracy 0.9672
# big_epoch: 63 start training...
# train_data_size 640
# epoch: 63 test_accuracy 0.952
# big_epoch: 64 start training...
# train_data_size 650
# epoch: 64 test_accuracy 0.9606
# big_epoch: 65 start training...
# train_data_size 660
# epoch: 65 test_accuracy 0.9612
# big_epoch: 66 start training...
# train_data_size 670
# epoch: 66 test_accuracy 0.9594
# big_epoch: 67 start training...
# train_data_size 680
# epoch: 67 test_accuracy 0.9608
# big_epoch: 68 start training...
# train_data_size 690
# epoch: 68 test_accuracy 0.9573
# big_epoch: 69 start training...
# train_data_size 700
# epoch: 69 test_accuracy 0.9605
# big_epoch: 70 start training...
# train_data_size 710
# epoch: 70 test_accuracy 0.9456
# big_epoch: 71 start training...
# train_data_size 720
# epoch: 71 test_accuracy 0.9553
# big_epoch: 72 start training...
# train_data_size 730
# epoch: 72 test_accuracy 0.9507
# big_epoch: 73 start training...
# train_data_size 740
# epoch: 73 test_accuracy 0.9598
# big_epoch: 74 start training...
# train_data_size 750
# epoch: 74 test_accuracy 0.9619
# big_epoch: 75 start training...
# train_data_size 760
# epoch: 75 test_accuracy 0.9608
# big_epoch: 76 start training...
# train_data_size 770
# epoch: 76 test_accuracy 0.9625
# big_epoch: 77 start training...
# train_data_size 780
# epoch: 77 test_accuracy 0.9543
# big_epoch: 78 start training...
# train_data_size 790
# epoch: 78 test_accuracy 0.9617
# big_epoch: 79 start training...
# train_data_size 800
# epoch: 79 test_accuracy 0.963
# big_epoch: 80 start training...
# train_data_size 810
# epoch: 80 test_accuracy 0.9673
# big_epoch: 81 start training...
# train_data_size 820
# epoch: 81 test_accuracy 0.9651
# big_epoch: 82 start training...
# train_data_size 830
# epoch: 82 test_accuracy 0.9663
# big_epoch: 83 start training...
# train_data_size 840
# epoch: 83 test_accuracy 0.969
# big_epoch: 84 start training...
# train_data_size 850
# epoch: 84 test_accuracy 0.9702
# big_epoch: 85 start training...
# train_data_size 860
# epoch: 85 test_accuracy 0.9707
# big_epoch: 86 start training...
# train_data_size 870
# epoch: 86 test_accuracy 0.9685
# big_epoch: 87 start training...
# train_data_size 880
# epoch: 87 test_accuracy 0.9653
# big_epoch: 88 start training...
# train_data_size 890
# epoch: 88 test_accuracy 0.9686
# big_epoch: 89 start training...
# train_data_size 900
# epoch: 89 test_accuracy 0.9728
# big_epoch: 90 start training...
# train_data_size 910
# epoch: 90 test_accuracy 0.9729
# big_epoch: 91 start training...
# train_data_size 920
# epoch: 91 test_accuracy 0.971
# big_epoch: 92 start training...
# train_data_size 930
# epoch: 92 test_accuracy 0.9687
# big_epoch: 93 start training...
# train_data_size 940
# epoch: 93 test_accuracy 0.9679
# big_epoch: 94 start training...
# train_data_size 950
# epoch: 94 test_accuracy 0.9725
# big_epoch: 95 start training...
# train_data_size 960
# epoch: 95 test_accuracy 0.97
# big_epoch: 96 start training...
# train_data_size 970
# epoch: 96 test_accuracy 0.9734
# big_epoch: 97 start training...
# train_data_size 980
# epoch: 97 test_accuracy 0.9725
# big_epoch: 98 start training...
# train_data_size 990
# epoch: 98 test_accuracy 0.9751
# big_epoch: 99 start training...
# train_data_size 1000
# epoch: 99 test_accuracy 0.9733
# [0.4085, 0.4948, 0.6042, 0.6745, 0.7165, 0.7289, 0.7411, 0.7988, 0.817, 0.8099, 0.8402, 0.8379, 0.8596, 0.8636, 0.8847, 0.8884, 0.8896, 0.8921, 0.8998, 0.8991, 0.9029, 0.901, 0.906, 0.9173, 0.913, 0.9195, 0.9249, 0.918, 0.9189, 0.9252, 0.9269, 0.927, 0.9374, 0.9314, 0.9397, 0.9406, 0.9374, 0.9347, 0.9482, 0.9457, 0.9434, 0.9511, 0.9396, 0.9467, 0.9443, 0.9449, 0.9444, 0.9512, 0.9463, 0.9475, 0.953, 0.947, 0.9498, 0.956, 0.9558, 0.9567, 0.9573, 0.9586, 0.9597, 0.9581, 0.9599, 0.9606, 0.9672, 0.952, 0.9606, 0.9612, 0.9594, 0.9608, 0.9573, 0.9605, 0.9456, 0.9553, 0.9507, 0.9598, 0.9619, 0.9608, 0.9625, 0.9543, 0.9617, 0.963, 0.9673, 0.9651, 0.9663, 0.969, 0.9702, 0.9707, 0.9685, 0.9653, 0.9686, 0.9728, 0.9729, 0.971, 0.9687, 0.9679, 0.9725, 0.97, 0.9734, 0.9725, 0.9751, 0.9733]
