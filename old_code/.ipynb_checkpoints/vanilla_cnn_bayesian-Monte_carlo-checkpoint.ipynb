# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
from hessian import *
import operator
torch.manual_seed(1)

# %%
train_data=torchvision.datasets.MNIST('./', train=True, download=True,transform=torchvision.transforms.ToTensor())
test_data=torchvision.datasets.MNIST('./', train=False, download=True,transform=torchvision.transforms.ToTensor())
# train_loader = torch.utils.data.DataLoader(train_data, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=100, shuffle=True)

# %%
train_dict={}
for (data, target) in train_data:
    if  target not in train_dict:
        train_dict[ target]=[]
        train_dict[ target].append(data)
    else:
        train_dict[ target].append(data)

# %%
initial_train_data=[]
initial_train_label=[]
for i in range(5):
    initial_train_data.append(train_dict[i][0])
    initial_train_label.append(i)
    
print(initial_train_label)
# Out:
# [0, 1, 2, 3, 4]

# %%
initial_train_data_tensor=torch.stack(initial_train_data)
initial_train_label_tensor=torch.tensor(initial_train_label)
train_x=torch.stack([data for (data, target) in train_data])
train_label=torch.tensor([target for (data, target) in train_data])
print(initial_train_data_tensor.size())
print(initial_train_label_tensor.size())
# Out:
# torch.Size([5, 1, 28, 28])
# torch.Size([5])

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)
        self.optimizer = optim.Adam(self.parameters(), lr=0.001)

        self.final_weight=nn.init.xavier_uniform_(torch.empty(10, 10,requires_grad = True),0.1)
        
#         for name, param in self.named_parameters():
#             if param.requires_grad:
#                 print (name, param.data)

    def forward(self, x):
        x=x.view(-1,1,28,28)
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x= torch.matmul(x,self.final_weight)
        return F.log_softmax(x,dim=-1)
    
    def predict(self,x):
        with torch.no_grad():
            output = torch.exp(self.forward(x))
            pred = output.data.max(dim=1, keepdim=True)[1]
            return pred
    
    def train(self,x,label):
        train_losses = []
        if x.size(0)>100:
            for it in range(0,1000):
                index=np.random.choice(x.size(0),100)
                self.optimizer.zero_grad()
                output = self.forward(x[index])
                loss = F.nll_loss(output,label[index])
                loss.backward()
                self.optimizer.step()
                train_losses.append(loss.item())
        
        else:    
            for it in range(0,1000):
                self.optimizer.zero_grad()
                output = self.forward(x)
                loss = F.nll_loss(output,label)
                loss.backward()
                self.optimizer.step()
                train_losses.append(loss.item())
        plt.plot(train_losses)
        plt.show()
        
        
    def test(self):
        correct=0
        for data, target in test_loader:
            pred = self.predict(data)
            correct += pred.eq(target.data.view_as(pred)).sum()
            correct_ratio= float(correct)/len(test_loader.dataset)
        return correct_ratio
        
    def uncertainty(self,x,label):
        output = torch.exp(self.forward(x))
        loss = F.nll_loss(output,torch.tensor([label]))+torch.norm(network.final_weight,2)
        jacobian_w=jacobian(output,self.final_weight)
        hessian_w=hessian(loss,self.final_weight)+torch.eye(100)*1e-6
        hessian_inverse=torch.inverse(hessian_w)
        left=torch.matmul(jacobian_w,hessian_inverse)
        pos_cov=torch.matmul(left,jacobian_w.t())
        (sign, logdet) = np.linalg.slogdet(pos_cov.detach().numpy()) 
        entropy=5+5*np.log(2*np.pi)+0.5*logdet
        return entropy

# %%
active_bnn = Net()
active_bnn.train(initial_train_data_tensor,initial_train_label_tensor)
# Out:
# conv1.weight tensor([[[[ 0.0189,  0.1038, -0.0233, -0.0491, -0.0006],
#           [ 0.0287, -0.1864, -0.1232,  0.0764, -0.0214],
#           [ 0.0777, -0.1744,  0.1556,  0.1843, -0.0749],
#           [ 0.1257,  0.1431,  0.0378, -0.0111, -0.1961],
#           [-0.0209,  0.1098,  0.0087, -0.1809, -0.1585]]],
#
#
#         [[[-0.1380,  0.1945,  0.0678,  0.0274,  0.0043],
#           [ 0.1209,  0.1119,  0.1388,  0.1724,  0.1872],
#           [-0.0442,  0.1324, -0.0803,  0.0893,  0.1128],
#           [-0.1841,  0.0459, -0.1646, -0.0016, -0.0819],
#           [ 0.1997, -0.0172,  0.1551,  0.1659,  0.0614]]],
#
#
#         [[[-0.0592, -0.0761,  0.1473,  0.1221,  0.0923],
#           [-0.0709, -0.1601,  0.0431,  0.1081, -0.1905],
#           [-0.0769, -0.1748,  0.1761,  0.0287, -0.1478],
#           [-0.1906, -0.1938,  0.0414,  0.1065, -0.0551],
#           [-0.1481, -0.1307, -0.1338,  0.1608,  0.0409]]],
#
#
#         [[[ 0.0134,  0.0823, -0.0656, -0.1373, -0.1907],
#           [ 0.1523,  0.1592, -0.0734,  0.0977,  0.0888],
#           [ 0.1126, -0.1289,  0.1432,  0.0500,  0.1284],
#           [-0.0559,  0.1501,  0.0366,  0.1283, -0.1974],
#           [ 0.0581, -0.0207,  0.0245, -0.0256, -0.1243]]],
#
#
#         [[[-0.1007,  0.1810, -0.1387,  0.1293,  0.0804],
#           [-0.1353,  0.1430,  0.1549,  0.0150,  0.0852],
#           [ 0.0565, -0.0098,  0.1667, -0.1654, -0.1465],
#           [-0.1705,  0.1734,  0.1312, -0.0346,  0.0387],
#           [ 0.0993,  0.0207,  0.0383, -0.0920,  0.1279]]],
#
#
#         [[[-0.0990, -0.1984, -0.1129, -0.0356, -0.0524],
#           [ 0.0010,  0.0496,  0.1710,  0.1804, -0.1718],
#           [ 0.0776, -0.0574,  0.0353,  0.0399,  0.1959],
#           [ 0.0324, -0.1326, -0.1240, -0.1536,  0.1802],
#           [ 0.1725, -0.1460,  0.0152, -0.1720,  0.1738]]],
#
#
#         [[[-0.1982, -0.0468,  0.0895, -0.1039, -0.0948],
#           [ 0.1457, -0.0080,  0.1217, -0.1045, -0.0409],
#           [ 0.1871, -0.0226, -0.0286, -0.0271,  0.1669],
#           [ 0.0087, -0.0857,  0.0216, -0.0193, -0.1049],
#           [-0.1218,  0.1760, -0.0904, -0.1211,  0.0046]]],
#
#
#         [[[-0.0153,  0.0351,  0.0755,  0.1726,  0.0949],
#           [-0.0417,  0.0547, -0.1202,  0.0481,  0.1318],
#           [ 0.0767, -0.1051, -0.1795, -0.0499,  0.1246],
#           [ 0.0548,  0.1746,  0.1823,  0.0230,  0.1030],
#           [-0.1784,  0.1481,  0.1825, -0.1120,  0.1602]]],
#
#
#         [[[-0.0688, -0.1416,  0.0773, -0.1132,  0.1231],
#           [ 0.1267,  0.0154,  0.0393, -0.1853, -0.0667],
#           [-0.1421, -0.1218,  0.0061, -0.0940, -0.1761],
#           1.1077e-01, -1.3347e-01,  5.7299e-02, -2.3013e-02, -9.6067e-02,
#          -1.3153e-01, -8.0943e-02, -7.2546e-02, -1.2903e-01,  2.8325e-02,
#           1.3161e-01, -1.1877e-01, -7.5549e-02, -1.2181e-01, -6.9681e-02,
#           5.3409e-02,  1.1484e-01, -7.9991e-02, -7.7883e-02,  3.1382e-02,
#          -1.3036e-01, -6.1800e-02,  2.0128e-02, -1.0439e-01,  4.2240e-02,
#           1.9067e-02, -1.2160e-02, -1.3003e-01,  1.1058e-01, -9.7648e-03,
#          -1.6104e-02, -1.0681e-01,  1.1786e-01, -8.2333e-02,  1.0566e-01],
#         [ 5.5637e-03,  5.9134e-03,  6.1248e-02, -1.1214e-01, -1.1138e-01,
#          -5.2363e-02,  1.2010e-02,  1.3673e-01, -2.0615e-02,  5.2041e-02,
#          -1.2385e-01,  6.6995e-02,  1.4225e-02, -1.1419e-02, -9.6573e-02,
#           6.3766e-03, -7.0656e-02, -1.8395e-02,  3.3654e-02,  8.9691e-02,
#          -1.2392e-02, -9.4812e-02,  3.4910e-02, -6.0147e-02, -7.6107e-02,
#          -1.0911e-01, -1.8075e-02,  8.4569e-02,  1.2427e-01, -8.1478e-02,
#           6.3077e-02,  1.3703e-01, -2.4140e-02, -5.0942e-02,  1.3362e-01,
#           2.5356e-04, -9.9722e-02, -9.5380e-02,  4.5635e-03,  2.8569e-02,
#           6.8418e-02,  2.5076e-02,  1.1059e-03, -1.2480e-01, -1.3213e-01,
#          -4.1861e-02,  1.0922e-01,  1.2003e-01,  1.0941e-01, -1.0542e-01],
#         [-6.2248e-02,  1.0085e-01, -9.6110e-02,  7.1383e-02,  7.6605e-02,
#          -8.9187e-02, -1.4039e-01, -1.3000e-01, -2.1052e-02, -3.9705e-02,
#           9.5542e-02,  4.8301e-02,  1.7479e-02, -6.8551e-03,  6.4645e-02,
#           9.6428e-02, -1.3979e-01, -1.1963e-01,  1.1723e-01, -1.3336e-01,
#          -2.1373e-02,  1.2345e-02, -8.0384e-02,  2.6590e-02,  4.2247e-02,
#           3.2022e-03, -7.6437e-02,  8.8650e-03,  6.8620e-02,  9.6319e-02,
#          -6.3597e-02, -8.7276e-02,  5.8484e-03,  1.3464e-01,  8.4456e-02,
#           2.2804e-02, -2.0464e-02,  4.5639e-02, -1.1827e-01, -2.2203e-02,
#          -1.1862e-01, -3.1306e-02,  7.0869e-02,  6.2562e-02,  6.0703e-02,
#           8.4548e-02, -4.9364e-02,  3.2988e-03,  1.2892e-02, -1.2462e-01]])
# fc2.bias tensor([ 0.1251, -0.0949, -0.0640, -0.1049, -0.0363,  0.0718,  0.0233,  0.1032,
#         -0.0361,  0.0743])

# %%
bnn_test_list=[]
bnn_test_list.append(active_bnn.test())
print(bnn_test_list)
# Out:
# [0.4308]

# %%
active_bnn = Net()
active_bnn.train(initial_train_data_tensor,initial_train_label_tensor)
bnn_test_list=[]
bnn_test_list.append(active_bnn.test())
print(bnn_test_list)
current_train=initial_train_data_tensor
current_label=initial_train_label_tensor
for epoch in range(60):
    index=np.random.choice(60000,10)
    current_train=torch.cat([current_train,train_x[index]],0)
    current_label=torch.cat([current_label,train_label[index]],0)
    active_bnn.train(current_train,current_label)
    ratio=active_bnn.test()
    print('ratio',ratio)
    bnn_test_list.append(ratio)
# Out:
# [0.3707]
# ratio 0.5271
# ratio 0.5785
# ratio 0.6836
# ratio 0.7093
# ratio 0.6977
# ratio 0.7492
# ratio 0.7608
# ratio 0.766
# ratio 0.7894
# ratio 0.7932
# ratio 0.7922
# ratio 0.8055
# ratio 0.8066
# ratio 0.8028
# ratio 0.8054
# ratio 0.8069
# ratio 0.8205
# ratio 0.822
# ratio 0.8387
# ratio 0.8367
# ratio 0.8515
# ratio 0.8511
# ratio 0.8511
# ratio 0.8511
# ratio 0.8537
# ratio 0.8584
# ratio 0.8729
# ratio 0.8747
# ratio 0.8778
# ratio 0.8901
# ratio 0.8908
# ratio 0.8869
# ratio 0.8902
# ratio 0.8881
# ratio 0.8876
# ratio 0.8967
# ratio 0.8984
# ratio 0.9073
# ratio 0.9094
# ratio 0.9123
# ratio 0.9165
# ratio 0.9169
# ratio 0.9181
# ratio 0.9187
# ratio 0.9187
# ratio 0.9175
# ratio 0.9199
# ratio 0.9196
# ratio 0.9208
# ratio 0.9188
# ratio 0.9157
# ratio 0.9191
# ratio 0.9191
# ratio 0.9203
# ratio 0.9183
# ratio 0.9203
# ratio 0.9211
# ratio 0.922
# ratio 0.9219
# ratio 0.9209

# %%
plt.plot(bnn_test_list,label='random sampling')
plt.plot(active_list,label='active learning')
plt.title('Sample efficiency comparison')
plt.xlabel('number of training data (*10)') 
plt.ylabel('accuracy on test dataset')
plt.legend()
plt.show()

# %%
current_train=initial_train_data_tensor
current_label=initial_train_label_tensor
for epoch in range(600):
    entropy_dict={}
    for i in range(epoch*1000,(epoch+1)*1000):
        train_epoch_x=train_x[i]
        train_epoch_label=train_label[i]
        entropy_dict[i]=active_bnn.uncertainty(train_x[i],train_label[i])
    sorted_dict = sorted(entropy_dict.items(), key=operator.itemgetter(1), reverse=True)
    sorted_index=[i[0] for i in sorted_dict[:10]]
    current_train=torch.cat([current_train,train_x[sorted_index]],0)
    current_label=torch.cat([current_label,train_label[sorted_index]],0)
    print(current_train.size())  
    print(current_label.size()) 
    active_bnn.train(current_train,current_label)
    ratio=active_bnn.test()
    print('ratio',ratio)
    bnn_test_list.append(ratio)
# Out:
# torch.Size([20, 1, 28, 28])
# torch.Size([20])
# ratio 0.6185
# torch.Size([30, 1, 28, 28])
# torch.Size([30])
# ratio 0.7087
# torch.Size([40, 1, 28, 28])
# torch.Size([40])
# ratio 0.7191
# torch.Size([50, 1, 28, 28])
# torch.Size([50])
# ratio 0.7344
# torch.Size([60, 1, 28, 28])
# torch.Size([60])
# ratio 0.7656
# torch.Size([70, 1, 28, 28])
# torch.Size([70])
# ratio 0.7898
# torch.Size([80, 1, 28, 28])
# torch.Size([80])
# ratio 0.831
# torch.Size([90, 1, 28, 28])
# ratio 0.939
# torch.Size([490, 1, 28, 28])
# torch.Size([490])
# ratio 0.9435
# torch.Size([500, 1, 28, 28])
# torch.Size([500])
# ratio 0.9462
# torch.Size([510, 1, 28, 28])
# torch.Size([510])
# ratio 0.9504
# torch.Size([520, 1, 28, 28])
# torch.Size([520])
# ratio 0.9496
# torch.Size([530, 1, 28, 28])
# torch.Size([530])
# ratio 0.9539
# torch.Size([540, 1, 28, 28])
# torch.Size([540])
# ratio 0.9542
# torch.Size([550, 1, 28, 28])
# torch.Size([550])
# ratio 0.9573
# torch.Size([560, 1, 28, 28])
# torch.Size([560])
# ratio 0.9563
# torch.Size([570, 1, 28, 28])
# torch.Size([570])
# ratio 0.9587
# torch.Size([580, 1, 28, 28])
# torch.Size([580])
# ratio 0.963
# torch.Size([590, 1, 28, 28])
# torch.Size([590])
# ratio 0.9591
# torch.Size([600, 1, 28, 28])
# torch.Size([600])
# ratio 0.9611
# torch.Size([610, 1, 28, 28])
# torch.Size([610])
# ratio 0.9601
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-146-5faf2aa6a5d7> in <module>
#       4     entropy_dict={}
#       5     for i in range(epoch*1000,(epoch+1)*1000):
# ----> 6         train_epoch_x=train_x[i]
#       7         train_epoch_label=train_label[i]
#       8         entropy_dict[i]=active_bnn.uncertainty(train_x[i],train_label[i])
#
# IndexError: index 60000 is out of bounds for dimension 0 with size 60000

# %%
active_list=[]
active_list.append(bnn_test_list[0])
active_list.extend(bnn_test_list[3:])
x_list=np.arange(1,62)*10
plt.plot(x_list,active_list)
plt.show()
# Out:
# [0.4308, 0.6717, 0.8553, 0.6185, 0.7087, 0.7191, 0.7344, 0.7656, 0.7898, 0.831, 0.834, 0.827, 0.8636, 0.8821, 0.8717, 0.8792, 0.8892, 0.9056, 0.9103, 0.9135, 0.9116, 0.9102, 0.9268, 0.9285, 0.9287, 0.9325, 0.9387, 0.9399, 0.933, 0.93, 0.9265, 0.9374, 0.9414, 0.9447, 0.9484, 0.9461, 0.9448, 0.9361, 0.9435, 0.9456, 0.9457, 0.9497, 0.9506, 0.9527, 0.951, 0.9475, 0.9404, 0.9412, 0.9361, 0.939, 0.9435, 0.9462, 0.9504, 0.9496, 0.9539, 0.9542, 0.9573, 0.9563, 0.9587, 0.963, 0.9591, 0.9611, 0.9601]

# %%
[0.4308, 0.6717, 0.8553, 0.6185, 0.7087, 0.7191, 0.7344, 0.7656, 0.7898, 0.831, 0.834, 0.827, 0.8636, 0.8821, 0.8717, 0.8792, 0.8892, 0.9056, 0.9103, 0.9135, 0.9116, 0.9102, 0.9268, 0.9285, 0.9287, 0.9325, 0.9387, 0.9399, 0.933, 0.93, 0.9265, 0.9374, 0.9414, 0.9447, 0.9484, 0.9461, 0.9448, 0.9361, 0.9435, 0.9456, 0.9457, 0.9497, 0.9506, 0.9527, 0.951, 0.9475, 0.9404, 0.9412, 0.9361, 0.939, 0.9435, 0.9462, 0.9504, 0.9496, 0.9539, 0.9542, 0.9573, 0.9563, 0.9587, 0.963, 0.9591, 0.9611, 0.9601]
